# %%
l=[9,0,67,0,8,8]
set(l)
# Out:
# {0, 8, 9, 67}

# %%
s={89,90,6,'p',78888888,4556,9,(8,88)}
s
# Out:
# {(8, 88), 4556, 6, 78888888, 89, 9, 90, 'p'}

# %%
s={89,90,6,'p',78888888,4556,9}
s[0]=9
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 s={89,90,6,'p',78888888,4556,9}
# ----> 2 s[0]=9
#
# TypeError: 'set' object does not support item assignment

# %%
s=[89,90,6,'p',78888888,4556,9]
s[0]=9
s
# Out:
# [9, 90, 6, 'p', 78888888, 4556, 9]

# %%
s={9,9,0}
s.add(7)
s
# Out:
# {0, 7, 9}

# %%
s={9,9,0}
s.update([7,0,9])
s
# Out:
# {0, 7, 9}

# %%
s={9,9,0}
s.add((8,9,0))
s
# Out:
# {(8, 9, 0), 0, 9}

# %%
s={9,9,0}
s.add(8,9,0)
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 s={9,9,0}
# ----> 2 s.add(8,9,0)
#       3 s
#
# TypeError: set.add() takes exactly one argument (3 given)

# %%
#remove or delete a value
s={4,5,6}
s.remove(6)
s
# Out:
# {4, 5}

# %%
s={4,5,6}
s.discard(5)
s
# Out:
# {4, 6}

# %%
s={4,5,6}
s.discard(50)
s
# Out:
# {4, 5, 6}

# %%
s={4,5,6}
s.pop()
s
# Out:
# {5, 6}

# %%
s=[6,18,90]
s.pop()
s
# Out:
# [6, 18]

# %%
s=[6,18,90]
s.pop(0)
# Out:
# 6
